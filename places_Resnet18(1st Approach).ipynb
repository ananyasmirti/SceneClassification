# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !mkdir Places2

# %%
import shutil 
shutil.unpack_archive("drive/MyDrive/Places2.zip", "Places2/")

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import numpy as np
import torchvision
from torchvision import *
from torch.utils.data import Dataset, DataLoader

import matplotlib.pyplot as plt
import time
import copy
import os

batch_size = 128
learning_rate = 1e-3

transforms = transforms.Compose(
[
    transforms.ToTensor()
])

train_dataset = datasets.ImageFolder(root='/content/Places2/Places2/train', transform=transforms)
test_dataset = datasets.ImageFolder(root='/content/Places2/Places2/test', transform=transforms)

train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=True)
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

def imshow(inp, title=None):
    
    inp = inp.cpu() if device else inp
    inp = inp.numpy().transpose((1, 2, 0))
    
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)
    
images, labels = next(iter(train_dataloader)) 
print("images-size:", images.shape)

out = torchvision.utils.make_grid(images)
print("out-size:", out.shape)

imshow(out, title=[train_dataset.classes[x] for x in labels])
# Out:
# images-size: torch.Size([128, 3, 256, 256])
# out-size: torch.Size([3, 4130, 2066])

# %%
# !nvidia-smi
# Out:
# Tue Jul  6 05:31:18 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.27       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   43C    P8     9W /  70W |      3MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
import torchvision.models as models

# %%
net = models.resnet18(pretrained=True)
net = net.cuda() 
net
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# HBox(children=(FloatProgress(value=0.0, max=46830571.0), HTML(value='')))
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=1000, bias=True)
# )

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import numpy as np
import torchvision
from torchvision import *
from torch.utils.data import Dataset, DataLoader

import matplotlib.pyplot as plt
import time
import copy
import os
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.0001, momentum=0.9)

def accuracy(out, labels):
    _,pred = torch.max(out, dim=1)
    return torch.sum(pred==labels).item()

num_ftrs = net.fc.in_features
net.fc = nn.Linear(num_ftrs, 128)
net.fc = net.fc.cuda()

# %%
n_epochs = 30
print_every = 10
valid_loss_min = np.Inf
val_loss = []
val_acc = []
train_loss = []
train_acc = []
total_step = len(train_dataloader)
for epoch in range(1, n_epochs+1):
    running_loss = 0.0
    correct = 0
    total=0
    print(f'Epoch {epoch}\n')
    for batch_idx, (data_, target_) in enumerate(train_dataloader):
        data_, target_ = data_.to(device), target_.to(device)
        optimizer.zero_grad()
        
        outputs = net(data_)
        loss = criterion(outputs, target_)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        _,pred = torch.max(outputs, dim=1)
        correct += torch.sum(pred==target_).item()
        total += target_.size(0)
        if (batch_idx) % 20 == 0:
            print ('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}' 
                   .format(epoch, n_epochs, batch_idx, total_step, loss.item()))
    train_acc.append(100 * correct / total)
    train_loss.append(running_loss/total_step)
    print(f'\ntrain-loss: {np.mean(train_loss):.4f}, train-acc: {(100 * correct/total):.4f}')
    batch_loss = 0
    total_t=0
    correct_t=0
    with torch.no_grad():
        net.eval()
        for data_t, target_t in (test_dataloader):
            data_t, target_t = data_t.to(device), target_t.to(device)
            outputs_t = net(data_t)
            loss_t = criterion(outputs_t, target_t)
            batch_loss += loss_t.item()
            _,pred_t = torch.max(outputs_t, dim=1)
            correct_t += torch.sum(pred_t==target_t).item()
            total_t += target_t.size(0)
        val_acc.append(100 * correct_t/total_t)
        val_loss.append(batch_loss/len(test_dataloader))
        network_learned = batch_loss < valid_loss_min
        print(f'validation loss: {np.mean(val_loss):.4f}, validation acc: {(100 * correct_t/total_t):.4f}\n')

        
        if network_learned:
            valid_loss_min = batch_loss
            torch.save(net.state_dict(), 'resnet.pt')
            print('Improvement-Detected, save-model')
    net.train()
# Out:
# Epoch 1
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# Epoch [1/30], Step [0/46], Loss: 4.9936
# Epoch [1/30], Step [20/46], Loss: 4.9609
# Epoch [1/30], Step [40/46], Loss: 4.8110
#
# train-loss: 4.9533, train-acc: 0.0860
# validation loss: 4.8748, validation acc: 0.4814
#
# Improvement-Detected, save-model
# Epoch 2
#
# Epoch [2/30], Step [0/46], Loss: 4.8455
# Epoch [2/30], Step [20/46], Loss: 4.8482
# Epoch [2/30], Step [40/46], Loss: 4.7753
#
# train-loss: 4.8643, train-acc: 0.1892
# validation loss: 4.7685, validation acc: 1.1004
#
# Improvement-Detected, save-model
# Epoch 3
#
# Epoch [3/30], Step [0/46], Loss: 4.6227
# Epoch [3/30], Step [20/46], Loss: 4.6361
# Epoch [3/30], Step [40/46], Loss: 4.4219
#
# train-loss: 4.7640, train-acc: 1.2386
# validation loss: 4.6569, validation acc: 2.9574
#
# Improvement-Detected, save-model
# Epoch 4
#
# Epoch [4/30], Step [0/46], Loss: 4.4586
# Epoch [4/30], Step [20/46], Loss: 4.3510
# Epoch [4/30], Step [40/46], Loss: 4.2262
#
# train-loss: 4.6545, train-acc: 6.5371
# validation loss: 4.5341, validation acc: 13.8239
#
# Improvement-Detected, save-model
# Epoch 5
#
# Epoch [5/30], Step [0/46], Loss: 4.2561
# Epoch [5/30], Step [20/46], Loss: 4.0932
# Epoch [5/30], Step [40/46], Loss: 3.9984
#
# train-loss: 4.5351, train-acc: 21.3487
# validation loss: 4.4016, validation acc: 30.8116
#
# Improvement-Detected, save-model
# Epoch 6
#
# Epoch [6/30], Step [0/46], Loss: 3.9732
# Epoch [6/30], Step [20/46], Loss: 3.8202
# Epoch [6/30], Step [40/46], Loss: 3.7581
#
# train-loss: 4.4086, train-acc: 38.3451
# validation loss: 4.2637, validation acc: 47.4553
#
# Improvement-Detected, save-model
# Epoch 7
#
# Epoch [7/30], Step [0/46], Loss: 3.5992
# Epoch [7/30], Step [20/46], Loss: 3.4999
# Epoch [7/30], Step [40/46], Loss: 3.3151
#
# train-loss: 4.2765, train-acc: 53.8276
# validation loss: 4.1274, validation acc: 60.3164
#
# Improvement-Detected, save-model
# Epoch 8
#
# Epoch [8/30], Step [0/46], Loss: 3.3794
# Epoch [8/30], Step [20/46], Loss: 3.2163
# Epoch [8/30], Step [40/46], Loss: 3.0827
#
# train-loss: 4.1409, train-acc: 63.2892
# validation loss: 3.9912, validation acc: 68.0193
#
# Improvement-Detected, save-model
# Epoch 9
#
# Epoch [9/30], Step [0/46], Loss: 2.9869
# Epoch [9/30], Step [20/46], Loss: 2.7256
# Epoch [9/30], Step [40/46], Loss: 3.1923
#
# train-loss: 4.0049, train-acc: 70.8584
# validation loss: 3.8558, validation acc: 73.3838
#
# Improvement-Detected, save-model
# Epoch 10
#
# Epoch [10/30], Step [0/46], Loss: 2.8174
# Epoch [10/30], Step [20/46], Loss: 2.6006
# Epoch [10/30], Step [40/46], Loss: 2.5476
#
# train-loss: 3.8700, train-acc: 76.5526
# validation loss: 3.7258, validation acc: 78.0605
#
# Improvement-Detected, save-model
# Epoch 11
#
# Epoch [11/30], Step [0/46], Loss: 2.4986
# Epoch [11/30], Step [20/46], Loss: 2.3293
# Epoch [11/30], Step [40/46], Loss: 2.3166
#
# train-loss: 3.7395, train-acc: 80.3200
# validation loss: 3.6005, validation acc: 81.2242
#
# Improvement-Detected, save-model
# Epoch 12
#
# Epoch [12/30], Step [0/46], Loss: 2.3389
# Epoch [12/30], Step [20/46], Loss: 2.2516
# Epoch [12/30], Step [40/46], Loss: 2.1549
#
# train-loss: 3.6147, train-acc: 83.3305
# validation loss: 3.4843, validation acc: 84.3191
#
# Improvement-Detected, save-model
# Epoch 13
#
# Epoch [13/30], Step [0/46], Loss: 2.0834
# Epoch [13/30], Step [20/46], Loss: 2.0636
# Epoch [13/30], Step [40/46], Loss: 2.0984
#
# train-loss: 3.4960, train-acc: 85.3260
# validation loss: 3.3750, validation acc: 85.9010
#
# Improvement-Detected, save-model
# Epoch 14
#
# Epoch [14/30], Step [0/46], Loss: 1.9778
# Epoch [14/30], Step [20/46], Loss: 2.0667
# Epoch [14/30], Step [40/46], Loss: 1.9588
#
# train-loss: 3.3845, train-acc: 87.2183
# validation loss: 3.2706, validation acc: 87.2765
#
# Improvement-Detected, save-model
# Epoch 15
#
# Epoch [15/30], Step [0/46], Loss: 1.8704
# Epoch [15/30], Step [20/46], Loss: 1.7851
# Epoch [15/30], Step [40/46], Loss: 1.8948
#
# train-loss: 3.2789, train-acc: 87.8032
# validation loss: 3.1719, validation acc: 88.1018
#
# Improvement-Detected, save-model
# Epoch 16
#
# Epoch [16/30], Step [0/46], Loss: 2.0031
# Epoch [16/30], Step [20/46], Loss: 1.5505
# Epoch [16/30], Step [40/46], Loss: 1.9702
#
# train-loss: 3.1801, train-acc: 89.2310
# validation loss: 3.0794, validation acc: 88.7208
#
# Improvement-Detected, save-model
# Epoch 17
#
# Epoch [17/30], Step [0/46], Loss: 1.5760
# Epoch [17/30], Step [20/46], Loss: 1.7245
# Epoch [17/30], Step [40/46], Loss: 1.8962
#
# train-loss: 3.0867, train-acc: 89.7471
# validation loss: 2.9925, validation acc: 89.2710
#
# Improvement-Detected, save-model
# Epoch 18
#
# Epoch [18/30], Step [0/46], Loss: 1.5798
# Epoch [18/30], Step [20/46], Loss: 1.4584
# Epoch [18/30], Step [40/46], Loss: 1.5417
#
# train-loss: 2.9993, train-acc: 89.9536
# validation loss: 2.9118, validation acc: 89.2710
#
# Improvement-Detected, save-model
# Epoch 19
#
# Epoch [19/30], Step [0/46], Loss: 1.4416
# Epoch [19/30], Step [20/46], Loss: 1.4688
# Epoch [19/30], Step [40/46], Loss: 1.3552
#
# train-loss: 2.9163, train-acc: 90.7105
# validation loss: 2.8354, validation acc: 89.5461
#
# Improvement-Detected, save-model
# Epoch 20
#
# Epoch [20/30], Step [0/46], Loss: 1.5088
# Epoch [20/30], Step [20/46], Loss: 1.3661
# Epoch [20/30], Step [40/46], Loss: 1.0985
#
# train-loss: 2.8385, train-acc: 90.8825
# validation loss: 2.7644, validation acc: 90.3026
#
# Improvement-Detected, save-model
# Epoch 21
#
# Epoch [21/30], Step [0/46], Loss: 1.4058
# Epoch [21/30], Step [20/46], Loss: 1.1837
# Epoch [21/30], Step [40/46], Loss: 1.2726
#
# train-loss: 2.7651, train-acc: 91.1061
# validation loss: 2.6969, validation acc: 90.1651
#
# Improvement-Detected, save-model
# Epoch 22
#
# Epoch [22/30], Step [0/46], Loss: 1.3440
# Epoch [22/30], Step [20/46], Loss: 1.1910
# Epoch [22/30], Step [40/46], Loss: 1.1976
#
# train-loss: 2.6958, train-acc: 91.2094
# validation loss: 2.6321, validation acc: 90.2338
#
# Improvement-Detected, save-model
# Epoch 23
#
# Epoch [23/30], Step [0/46], Loss: 1.1608
# Epoch [23/30], Step [20/46], Loss: 1.0669
# Epoch [23/30], Step [40/46], Loss: 1.0541
#
# train-loss: 2.6303, train-acc: 91.5190
# validation loss: 2.5724, validation acc: 90.2338
#
# Improvement-Detected, save-model
# Epoch 24
#
# Epoch [24/30], Step [0/46], Loss: 0.9777
# Epoch [24/30], Step [20/46], Loss: 1.3573
# Epoch [24/30], Step [40/46], Loss: 1.2007
#
# train-loss: 2.5684, train-acc: 91.4502
# validation loss: 2.5151, validation acc: 90.1651
#
# Improvement-Detected, save-model
# Epoch 25
#
# Epoch [25/30], Step [0/46], Loss: 1.1880
# Epoch [25/30], Step [20/46], Loss: 1.0852
# Epoch [25/30], Step [40/46], Loss: 1.2077
#
# train-loss: 2.5101, train-acc: 91.7426
# validation loss: 2.4622, validation acc: 90.3026
#
# Improvement-Detected, save-model
# Epoch 26
#
# Epoch [26/30], Step [0/46], Loss: 1.2135
# Epoch [26/30], Step [20/46], Loss: 1.3060
# Epoch [26/30], Step [40/46], Loss: 0.9865
#
# train-loss: 2.4550, train-acc: 91.9663
# validation loss: 2.4109, validation acc: 90.3714
#
# Improvement-Detected, save-model
# Epoch 27
#
# Epoch [27/30], Step [0/46], Loss: 0.8846
# Epoch [27/30], Step [20/46], Loss: 1.1633
# Epoch [27/30], Step [40/46], Loss: 1.0404
#
# train-loss: 2.4025, train-acc: 91.9835
# validation loss: 2.3629, validation acc: 90.5089
#
# Improvement-Detected, save-model
# Epoch 28
#
# Epoch [28/30], Step [0/46], Loss: 1.0567
# Epoch [28/30], Step [20/46], Loss: 0.6646
# Epoch [28/30], Step [40/46], Loss: 1.0178
#
# train-loss: 2.3523, train-acc: 92.2587
# validation loss: 2.3167, validation acc: 90.5777
#
# Improvement-Detected, save-model
# Epoch 29
#
# Epoch [29/30], Step [0/46], Loss: 0.6849
# Epoch [29/30], Step [20/46], Loss: 0.9804
# Epoch [29/30], Step [40/46], Loss: 1.1937
#
# train-loss: 2.3047, train-acc: 92.2759
# validation loss: 2.2732, validation acc: 90.7153
#
# Improvement-Detected, save-model
# Epoch 30
#
# Epoch [30/30], Step [0/46], Loss: 0.8827
# Epoch [30/30], Step [20/46], Loss: 0.8836
# Epoch [30/30], Step [40/46], Loss: 1.2536
#
# train-loss: 2.2593, train-acc: 92.1899
# validation loss: 2.2318, validation acc: 90.7840
#
# Improvement-Detected, save-model

# %%
torch.save(net, '/content/Places2/modelResnet18.pth')

# %%
torch.save(net.state_dict(), "/content/Places2/cifar10_model")

# %%
clf = CIFAR10_clf()
clf.load("cifar10_model")

# Make predictions
predicted = clf.predict(images)

# %%
fig = plt.figure(figsize=(20,10))
plt.title("Train-Validation Accuracy")
plt.plot(train_acc, label='train')
plt.plot(val_acc, label='validation')
plt.xlabel('num_epochs', fontsize=12)
plt.ylabel('accuracy', fontsize=12)
plt.legend(loc='best')

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
net=torch.load('/content/Places2/modelResnet18.pth')
net.eval()
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=128, bias=True)
# )

# %%
use_cuda = torch.cuda.is_available()
def visualize_model(net, num_images=10):
    images_so_far = 0
    fig = plt.figure(figsize=(15, 10))
    
    for i, data in enumerate(test_dataloader):
        inputs, labels = data
        if use_cuda:
            inputs, labels = inputs.cuda(), labels.cuda()
        outputs = net(inputs)
        _, preds = torch.max(outputs.data, 1)
        preds = preds.cpu().numpy() if use_cuda else preds.numpy()
        for j in range(inputs.size()[0]):
            images_so_far += 1
            ax = plt.subplot(2, num_images//2, images_so_far)
            ax.axis('off')
            ax.set_title('predictes: {}'.format(test_dataset.classes[preds[j]]))
            imshow(inputs[j])
            
            if images_so_far == num_images:
                return 

plt.ion()
visualize_model(net)
plt.ioff()
